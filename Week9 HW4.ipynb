# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('https://apiservice.mol.gov.tw/OdService/download/A17000000J-020078-LPO')

# %%
df
# Out:
#    統計項目別               細項  樣本數（人）  很滿意（%）  滿意（%）  普通（%） 不滿意（%） 很不滿意（%）
# 0     性別                男    1891    12.5   54.0   29.9    3.2     0.5
# 1     性別                女    2191    11.8   57.2   28.0    2.6     0.4
# 2     年齡           15-24歲     246    15.7   49.8   33.1    1.4       -
# 3     年齡           25-44歲    2573    11.0   55.5   29.5    3.5     0.5
# 4     年齡           25-34歲    1348    10.5   54.6   30.8    3.4     0.7
# 5     年齡           35-44歲    1225    11.5   56.5   27.9    3.6     0.4
# 6     年齡           45-64歲    1241    13.6   57.5   26.8    1.9     0.2
# 7     年齡           45-54歲     857    13.0   56.1   28.4    2.1     0.3
# 8     年齡           55-64歲     384    15.0   60.8   22.8    1.3     0.1
# 9     年齡            65歲以上      22    30.4   58.3   11.3      -       -
# 10  教育程度            國中及以下     315    14.8   54.7   28.8    1.7       -
# 11  教育程度            高中（職）    1222    12.3   56.6   28.3    2.3     0.6
# 12  教育程度            專科及大學    2215    11.6   54.8   29.7    3.5     0.4
# 13  教育程度            碩士及以上     330    12.4   60.0   25.4      2     0.2
# 14  每月收入        未滿19,047元     103    19.7   47.5   28.4    4.3       -
# 15  每月收入    19,047元-未滿2萬元     164    16.7   54.5   27.5    1.3       -
# 16  每月收入       2萬-未滿2.5萬元     451    16.2   47.5   33.4    2.5     0.4
# 17  每月收入       2.5萬-未滿3萬元     644     9.4   54.8   32.2    2.8     0.8
# 18  每月收入         3萬-未滿4萬元    1098    10.2   56.3   29.3    3.7     0.4
# 19  每月收入         4萬-未滿6萬元    1273    10.3   59.0   27.8    2.5     0.5
# 20  每月收入         6萬-未滿8萬元     229    16.5   57.7   22.0    3.6     0.1
# 21  每月收入        8萬-未滿10萬元      58    25.4   55.6   16.8    2.1       -
# 22  每月收入           10萬元以上      62    26.6   57.2   16.2      -       -
# 23    地區             北部地區    2232    12.1   54.5   29.9      3     0.5
# 24    地區             中部地區     840    12.1   56.2   28.2    3.3     0.3
# 25    地區             南部地區     830    12.2   59.2   26.0    2.2     0.3
# 26    地區             東部地區     180    13.2   51.6   32.9    1.2     1.1
# 27    規模            29人以下    1459    14.4   57.3   26.2    1.9     0.1
# 28    規模           30-49人     411    12.6   54.7   30.1    2.6       -
# 29    規模          50-199人     851    10.7   53.8   30.7    3.9     0.9
# ..   ...              ...     ...     ...    ...    ...    ...     ...
# 43    行業           批發及零售業     850    13.0   57.0   27.1    2.8     0.2
# 44    行業           運輸及倉儲業     137    15.8   52.0   30.6    1.4     0.2
# 45    行業           住宿及餐飲業     124    13.4   53.3   31.6    1.6       -
# 46    行業         資訊及通訊傳播業     115    12.9   51.2   32.9    3.1       -
# 47    行業           金融及保險業     219    14.2   54.6   27.6      3     0.5
# 48    行業             不動產業      68    18.9   55.6   25.1      -     0.4
# 49    行業      專業、科學及技術服務業     167    10.8   54.0   32.3    2.9       -
# 50    行業            支援服務業     124     9.3   61.6   27.5    1.6       -
# 51    行業  公共行政及國防;強制性社會安全     118     5.2   68.4   23.6    1.8     0.9
# 52    行業            教育服務業     141    12.7   62.6   20.8    2.4     1.4
# 53    行業     醫療保健及社會工作服務業     169    13.2   51.2   31.7    3.3     0.6
# 54    行業      藝術、娛樂及休閒服務業      44    17.2   61.8   16.5    4.5       -
# 55    行業            其他服務業      98    17.8   61.9   20.3      -       -
# 56    職業     民意代表、主管及經理人員     296    18.4   64.3   15.9    1.4       -
# 57    職業             專業人員     666    10.0   54.8   30.6    4.4     0.2
# 58    職業       技術員及助理專業人員     880    10.8   54.4   30.6    3.7     0.5
# 59    職業           事務支援人員    1015    12.3   59.8   26.1    1.4     0.5
# 60    職業        服務及銷售工作人員     417    15.3   54.4   28.8      1     0.4
# 61    職業        農林漁牧業生產人員      25    22.0   68.8    7.9    1.3       -
# 62    職業         技藝有關工作人員     177    12.5   53.0   29.9    3.4     1.2
# 63    職業      機械設備操作及組裝人員     318     8.7   50.2   37.4    3.7       -
# 64    職業        基層技術工及勞力工     288    12.5   48.0   33.1      5     1.5
# 65  工作年資             未滿2年     201    12.7   54.3   30.6    2.4       -
# 66  工作年資          2年-未滿5年     431    11.3   52.9   32.5    2.8     0.6
# 67  工作年資         5年-未滿10年     716    12.2   52.8   30.3    4.1     0.6
# 68  工作年資        10年-未滿15年     711    11.7   55.9   28.7    3.4     0.3
# 69  工作年資        15年-未滿20年     610    11.5   57.4   28.0    2.6     0.6
# 70  工作年資        20年-未滿25年     524    12.5   57.8   26.1    3.2     0.4
# 71  工作年資        25年-未滿30年     377    12.1   57.9   28.4    1.2     0.4
# 72  工作年資            30年以上     512    13.6   57.4   26.9    1.8     0.3
#
# [73 rows x 8 columns]

# %%
df_sorted=df

# %% [markdown]
# ## 職業

# %%
df1 = df_sorted[df_sorted.統計項目別=='職業']

# %%
df1
# Out:
#    統計項目別            細項  樣本數（人）  很滿意（%）  滿意（%）  普通（%） 不滿意（%） 很不滿意（%）
# 56    職業  民意代表、主管及經理人員     296    18.4   64.3   15.9    1.4       -
# 57    職業          專業人員     666    10.0   54.8   30.6    4.4     0.2
# 58    職業    技術員及助理專業人員     880    10.8   54.4   30.6    3.7     0.5
# 59    職業        事務支援人員    1015    12.3   59.8   26.1    1.4     0.5
# 60    職業     服務及銷售工作人員     417    15.3   54.4   28.8      1     0.4
# 61    職業     農林漁牧業生產人員      25    22.0   68.8    7.9    1.3       -
# 62    職業      技藝有關工作人員     177    12.5   53.0   29.9    3.4     1.2
# 63    職業   機械設備操作及組裝人員     318     8.7   50.2   37.4    3.7       -
# 64    職業     基層技術工及勞力工     288    12.5   48.0   33.1      5     1.5

# %% [markdown]
# ### 職業樣本人數

# %%
dfm_sort  = dfm.sort_values('樣本數（人）', ascending = False)

# %%
dfm_sort
# Out:
#    統計項目別            細項  樣本數（人）  很滿意（%）  滿意（%）  普通（%） 不滿意（%） 很不滿意（%）
# 59    職業        事務支援人員    1015    12.3   59.8   26.1    1.4     0.5
# 58    職業    技術員及助理專業人員     880    10.8   54.4   30.6    3.7     0.5
# 57    職業          專業人員     666    10.0   54.8   30.6    4.4     0.2
# 60    職業     服務及銷售工作人員     417    15.3   54.4   28.8      1     0.4
# 63    職業   機械設備操作及組裝人員     318     8.7   50.2   37.4    3.7       -
# 56    職業  民意代表、主管及經理人員     296    18.4   64.3   15.9    1.4       -
# 64    職業     基層技術工及勞力工     288    12.5   48.0   33.1      5     1.5
# 62    職業      技藝有關工作人員     177    12.5   53.0   29.9    3.4     1.2
# 61    職業     農林漁牧業生產人員      25    22.0   68.8    7.9    1.3       -

# %% [markdown]
# ### 很滿意與滿意

# %%
dfm["滿意與很滿意加總"]=dfm.iloc[:, 3:5].sum(axis=1)
dfm_sort  = dfm.sort_values('滿意與很滿意加總', ascending = False)
dfm_sort
# Out:
# C:\Users\ASUS\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#    統計項目別            細項  樣本數（人）  很滿意（%）  滿意（%）  普通（%） 不滿意（%） 很不滿意（%）  滿意與很滿意加總
# 61    職業     農林漁牧業生產人員      25    22.0   68.8    7.9    1.3       -      90.8
# 56    職業  民意代表、主管及經理人員     296    18.4   64.3   15.9    1.4       -      82.7
# 59    職業        事務支援人員    1015    12.3   59.8   26.1    1.4     0.5      72.1
# 60    職業     服務及銷售工作人員     417    15.3   54.4   28.8      1     0.4      69.7
# 62    職業      技藝有關工作人員     177    12.5   53.0   29.9    3.4     1.2      65.5
# 58    職業    技術員及助理專業人員     880    10.8   54.4   30.6    3.7     0.5      65.2
# 57    職業          專業人員     666    10.0   54.8   30.6    4.4     0.2      64.8
# 64    職業     基層技術工及勞力工     288    12.5   48.0   33.1      5     1.5      60.5
# 63    職業   機械設備操作及組裝人員     318     8.7   50.2   37.4    3.7       -      58.9
