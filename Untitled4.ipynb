# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_excel("成人脂肪平均值及肥胖盛行率.xls")

# %%
df
# Out:
#     體脂肪   平均值  標準誤  過高比率  過高人數
# 0    男性  24.4  0.7  49.4    50
# 1   NaN  23.6  0.7  53.0    39
# 2   NaN  23.5  2.4  45.0    35
# 3   NaN  24.3  0.7  50.5    41
# 4   NaN  23.7  0.6  36.9    20
# 5   NaN  23.3  1.2  46.2    50
# 6   NaN  28.2  2.0  70.9    29
# 7   NaN  23.4  1.3  49.7    34
# 8    女性  35.3  0.6  80.5    80
# 9   NaN  33.4  0.3  72.0    48
# 10  NaN  36.0  0.7  84.3    54
# 11  NaN  36.7  0.6  85.2    73
# 12  NaN  35.6  1.2  82.5    45
# 13  NaN  35.4  1.2  80.2    83
# 14  NaN  37.8  0.3  86.4    48
# 15  NaN  32.5  0.5  57.9    35

# %%
df.drop("過高比率", axis=1, inplace=True)
df.drop("體脂肪", axis=1, inplace=True)

# %%
df
# Out:
#      平均值  標準誤  過高人數
# 0   24.4  0.7    50
# 1   23.6  0.7    39
# 2   23.5  2.4    35
# 3   24.3  0.7    41
# 4   23.7  0.6    20
# 5   23.3  1.2    50
# 6   28.2  2.0    29
# 7   23.4  1.3    34
# 8   35.3  0.6    80
# 9   33.4  0.3    48
# 10  36.0  0.7    54
# 11  36.7  0.6    73
# 12  35.6  1.2    45
# 13  35.4  1.2    83
# 14  37.8  0.3    48
# 15  32.5  0.5    35

# %%
df.平均值.plot()
