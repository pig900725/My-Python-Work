# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_excel("pd.xls")

# %%
df.head(22)
# Out:
#            罪名別   106年   107年
# 0          瀆職罪     62     37
# 1        公共危險罪  61387  59046
# 2      偽造文書印文罪   3562   3450
# 3       妨害性自主罪   1496   1512
# 4        妨害風化罪   1429   1358
# 5          賭博罪   7280   5400
# 6          殺人罪   1609   1597
# 7          傷害罪  10717  11271
# 8        妨害自由罪   4623   4538
# 9          竊盜罪  21764  21724
# 10         強盜罪    389    372
# 11         搶奪罪    353    275
# 12         侵占罪   2511   2666
# 13         詐欺罪  12313  14111
# 14      背信及重利罪    672    511
# 15         恐嚇罪    568    611
# 16       擄人勒贖罪     15      5
# 17      貪污治罪條例    334    362
# 18  槍砲彈藥刀械管制條例   1445   1708
# 19    毒品危害防制條例  43281  44541
# 20          其他  16729  17460

# %% [markdown]
# ### 兩年內犯罪件數

# %%
df["總件數"]=df.loc[:,"106年":"107年"].sum(axis=1)

# %%
df.head(22)
# Out:
#            罪名別   106年   107年     總件數
# 0          瀆職罪     62     37      99
# 1        公共危險罪  61387  59046  120433
# 2      偽造文書印文罪   3562   3450    7012
# 3       妨害性自主罪   1496   1512    3008
# 4        妨害風化罪   1429   1358    2787
# 5          賭博罪   7280   5400   12680
# 6          殺人罪   1609   1597    3206
# 7          傷害罪  10717  11271   21988
# 8        妨害自由罪   4623   4538    9161
# 9          竊盜罪  21764  21724   43488
# 10         強盜罪    389    372     761
# 11         搶奪罪    353    275     628
# 12         侵占罪   2511   2666    5177
# 13         詐欺罪  12313  14111   26424
# 14      背信及重利罪    672    511    1183
# 15         恐嚇罪    568    611    1179
# 16       擄人勒贖罪     15      5      20
# 17      貪污治罪條例    334    362     696
# 18  槍砲彈藥刀械管制條例   1445   1708    3153
# 19    毒品危害防制條例  43281  44541   87822
# 20          其他  16729  17460   34189

# %% [markdown]
# ### 犯罪排行前五名

# %%
df_sort=df.sort_values("總件數",ascending=False)

# %%
df_sort.head()
# Out:
#          罪名別   106年   107年     總件數
# 1      公共危險罪  61387  59046  120433
# 19  毒品危害防制條例  43281  44541   87822
# 9        竊盜罪  21764  21724   43488
# 20        其他  16729  17460   34189
# 13       詐欺罪  12313  14111   26424

# %% [markdown]
# ### 犯罪折線圖

# %%
df.總件數.plot()
